# %%
class Oceano:
    
    america = False
    nombre_oceano = None
    ubicacion = None
    pais_acceso = None
    metros_cuadrados = 0
    
    def __init__(self, nombre_oceano,ubicacion,pais_acceso,metros_cuadrados,america):
        self.nombre_oceano = nombre_oceano
        self.ubicacion = ubicacion
        self.pais_acceso = pais_acceso
        self.metros_cuadrados = metros_cuadrados
        self.america = america
        
    
    def __str__(self):
        return f"{self.nombre_oceano},{self.ubicacion},{self.pais_acceso},{self.metros_cuadrados},{self.america}\n"
        
        
            
    
def agregar_oceano():                    
    nombre_oceano = input("Ingrese el nombre del Ocenao: ")
    ubicacion = input("En que continente se encuentra?: ")
    pais_acceso = input("un pais que tenga acceso a ese oceano: ")
    metros_cuadrados = input("cual es el valor de la supercie: ")
    america = input("Escriba True si se encuentra en america o False si no es asi")
    oceano.append(Oceano(nombre_oceano,ubicacion,pais_acceso ,metros_cuadrados,america))
    
def eliminar_oceano():
    nombre = input("Ingrese el nombre del oceano que quiere eliminar ")
    encontrado = False
    for i in oceano:
        a = i.split(";")
        if(nombre== a[0]):
            encontrado = True
            oceano.remove(i)
            break
    if(encontrado ==  False):
        print("No hay esa especie")


def actualizar_especie_marina():
    nombre = input("Ingrese el nombre de la especie que quiere actualizar ")
    encontrado = False
    for i in oceano:
        a = i.split(";")
        if (nombre == a[0]):
            encontrado = True
            oceano.remove(i)
            agregar_oceano()
            break
    if (encontrado == False):
        print("No hay esa especie")

def mostrar_oceanos():
    for l in oceano:
        print(l)

def escribir_titulo():
    
    try:
        path = "./oceanos.txt"
        archivo_abierto = open(path, 'w')
        linea = ""
        
        linea+=("Nombre Oceano; Ubicacion; Pais con acceso; Metros cuadrados; En America?\n")
        archivo_abierto.write(linea)    
        archivo_abierto.close()
        print("estoy en try escribir")
    except Exception as err:
        print("estoy en catch escribir")
        print(err)

def escribir_archivo_oceano():
    try:
        path = "./oceanos.txt"
        archivo_abierto = open(path, 'a')
        linea = ""
        for l in oceano:
            linea+=l.nombre_oceano+";"+l.ubicacion+";"+l.pais_acceso+";"+l.metros_cuadrados+";"+l.america+"\n"
        archivo_abierto.append(linea)    
        archivo_abierto.close()
        print("estoy en try escribir")
    except Exception as err:
        print("estoy en catch escribir")
        print(err)
    
        
def leer_archivo_oceanos():
    
    try:
        path = "./oceanos.txt"
        archivo_abierto = open(path, 'r+')
        l =""
        for i in archivo_abierto:
            e = i.split(";")
            print(len(e))
            l+= oceano.append(Oceano(e[0],e[1],e[2],e[3],e[4]))
            
        archivo_abierto.close()

    except Exception as err:
        print(err)
        print("estoy en catch leer")
            

    
oceano = []
leer_archivo_oceanos()
mostrar_oceanos()
# Out:
# 5
# can only concatenate str (not "NoneType") to str
# estoy en catch leer
# Nombre Oceano, Ubicacion, Pais con acceso, Metros cuadrados, En America?

# %%
class Especie_maritima:
    vertebrado = False  # bool
    nombre_comun = None  # String
    oceano = None  # string
    promedio_vida = None  # Int
    tamanio_promedio = 0  # float

    def __init__(self, nombre_comun, oceano, promedio_vida, tamanio_promedio, vertebrado):
        self.nombre_comun = nombre_comun
        self.oceano = oceano
        self.promedio_vida = promedio_vida
        self.tamanio_promedio = tamanio_promedio
        self.vertebrado = vertebrado

    def __str__(self):
        return f"{self.nombre_comun},{self.oceano},{self.promedio_vida},{self.tamanio_promedio},{self.vertebrado}\n"
        

def menu_especies():
    while True:
        print("Menu especies \n")
        print("opciones ...")
        print("1. Agregar una especie")
        print("2. Actualizar una especie")
        print("3. Ver una especie")
        print("4. Eliminar una especie")
        print("5. Salir")
        accion = input("Escriba el numero de la accion que desea hacer: ")

        try:
            opcion = int(accion)
            if( opcion <1 or opcion > 6 ):
                print("Ingrese un numero entre 1 y 5")
                continue
            else:
                break

        except ValueError as err:
            print("ingrese un valor numerico")
            continue

    def agregar_esp():
        agregar_especie_marina()
    def actualizar():
        actualizar_especie_marina()
    def leer_esp():
        mostrar_especie_marina()
    def borrar():
        eliminar_especie_marina()
    def salir():
        exit()
    def llamada_funciones():
        opciones = {
            1:agregar_esp,
            2:actualizar,
            3:leer_esp,
            4:borrar,
            5:salir
        }


        return opciones[opcion]()

    return llamada_funciones()

def agregar_especie_marina():
    nombre_comun = input("Ingrese el nombre comun de la especie marina: ")
    oceano = input("Ingrese el nombre del oceano donde se encuentra a la especie:")
    promedio_vida = input("ingrese el promedio de vida de la especie marina: ")
    tamanio_promedio = input("ingrese el tamanio promedio de la especie marina: ")
    vertebrado = input("Escriba True en caso de que la especie sea vertebrado, caso contrario escriba False: ")
    especies.append(Especie_maritima(nombre_comun, oceano, promedio_vida, tamanio_promedio,vertebrado))

def eliminar_especie_marina():
    nombre = input("Ingrese el nombre de la especie que quiere eliminar ")
    encontrado = False
    for i in especies:
        a = i.split("-")
        if(nombre ):

            encontrado = True
            especies.remove(i)
            break
    if(encontrado ==  False):
        print("No hay esa especie")


def actualizar_especie_marina():
    nombre = input("Ingrese el nombre de la especie que quiere actualizar ")
    encontrado = False
    for i in especies:
        a = i.split(";")
        if (nombre == a[0]):
            encontrado = True
            especies.remove(i)
            agregar_especie_marina(especies)
            break
    if (encontrado == False):
        print("No hay esa especie")

def mostrar_especie_marina():
    for l in especies:
        print(l)

def escribir_archivo_especies():    
    try:
        path = "especies.txt"
        archivo_especies = open(path,'w')
        campos = ""
        for l in especies:
            campos += l.nombre_comun+";"+l.oceano+";"+l.promedio_vida+";"+l.tamanio_promedio+";"+l.vertebrado+"\n"
        print(campos)
        archivo_especies.write(campos)            
        archivo_especies.close()
    except Exception as err:
        print('eroro al escrivir1')

def leer_archivo_especies():
    
    try:
        path = "especies.txt"
        archivo = open(path,'r')
        
        for l in archivo:
            e = l.split(";")
            especies.append(Especie_maritima(e[0],e[1],e[2],e[3],e[4]))
        archivo.close()
    except Exception as err:
        print(err)
        

if __name__=="__main__":
    especies = []
    agregar_especie_marina()
    #leer_archivo_especies()
    #menu_especies()
    print(especies)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-a7b883fe8f2a> in <module>
#     132 if __name__=="__main__":
#     133     especies = []
# --> 134     agregar_especie_marina()
#     135     #leer_archivo_especies()
#     136     #menu_especies()
#
# <ipython-input-19-a7b883fe8f2a> in agregar_especie_marina()
#      65
#      66 def agregar_especie_marina():
# ---> 67     nombre_comun = input("Ingrese el nombre comun de la especie marina: ")
#      68     oceano = input("Ingrese el nombre del oceano donde se encuentra a la especie:")
#      69     promedio_vida = input("ingrese el promedio de vida de la especie marina: ")
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
