# %%
class Ocenano:
    
    __america = False
    __nombre_oceano = None
    __ubicacion = None
    __paises_con_acceso = None
    __metros_cuadrados = 0
    __archivo_abierto = None
    
    def __init__(self):
        print("inicie constructor")
        
            
    def escribir_datos(l):
        try:
            path = "./oceanos.txt"
            archivo_abierto = open(path, "a")    
            archivo_abierto.write(l)           
            archivo_abierto.close()

        except Exception as error:
            print("error leyendo archivo" + error)
            
    def leer_archivo():
        try:
            path = "./oceanos.txt"
            archivo_abierto = open(path, "r")
            texto = archivo_abierto.readlines()
            archivo_abierto.close()
            print(texto)
        except Exception as error:
            print("no se puede leer el archivo")
    
    
    def eliminar_linea():
        eliminar = input("desea eliminar la ultima linea, escriba si o no? ")
        aux = 0
        if eliminar == "si":
            try:
                path = "./oceanos.txt"
                archivo_abierto = open(path, "r+")
                texto = archivo_abierto.readlines()
                texto.pop()
                archivo_abierto.close()
                print(texto)
            except Exception as error:
                print("no se puede eliminar la linea")
        else:
            print("okey")
                        
    __nombre_oceano = input("Ingrese el nombre del Ocenao: ")
    __ubicacion = input("En que lugar se encuentra?:")
    __paises_con_acceso = input("un pais que tenga acceso a ese oceano: ")
    __metros_cuadrados = input("cual es el valor de la supercie: \n")
    
    if __nombre_oceano == "pacifico" or "Atlantico":
        __america = True
             
    linea = f"{__nombre_oceano} {__ubicacion} {__paises_con_acceso} {str(__metros_cuadrados)} {str(__america)}\n"  
    
    
        
    escribir_datos(linea)
    leer_archivo()
    eliminar_linea()
# Out:
# Ingrese el nombre del Ocenao: asdfasd
# En que lugar se encuentra?:asdfasdf
# un pais que tenga acceso a ese oceano: asdfasdf
# cual es el valor de la supercie:
# 45654
# ['artico europa alemania 12345 True\n', 'pacifico america ecuador 147852 True\n', 'atlantico america colombia 963852 True\n', 'pacifico america peru 456785 True\n']
# desea eliminar la ultima linea, escriba si o no? si
# ['artico europa alemania 12345 True\n', 'pacifico america ecuador 147852 True\n', 'atlantico america colombia 963852 True\n']

# %%
class Especie_Maritima:

    __vertebrado = False  # bool
    __nombre_comun = None  # String
    __nombre_cientifico = None  # string
    __promedio_vida = None  # Int
    __tamanio_promedio = 0  # float
    
    path_especies = "./especies.txt"

    def __init__(self, vertebrado, nombre_comun, nombre_cientifico, promedio_vida, tamanio_promedio):
        print("inicie constructor")
        self.__nombre_comun = nombre_comun
        self.__nombre_cientifico = nombre_cientifico
        self.__promedio_vida = promedio_vida
        self.__tamanio_promedio = tamanio_promedio
        self.__vertebrado = vertebrado


        

    
    def escribir_datos(l):
        try:
            path = "./especies.txt"
            archivo_abierto = open(path, "a")    
            archivo_abierto.write(l)           
            archivo_abierto.close()

        except Exception as error:
            print("error leyendo archivo" + error)
    
    def leer_archivo_especies():
        try:
            path_especies = "./especies.txt"
            archivo = open(path_especies,"r")
            texto = archivo.readlines()
            archivo.close()
            print(texto)
        except Exception as error:
            print("no se puede leer el archivo")
    
    def escribir_archivo_especies(l):
        try:
            path_especies = "./especies.txt"
            archivo = open(path_especies,"r+")
            texto = archivo.write(l)
            archivo.close()
        except Exception as error:
            print("no se puede leer el archivo")
        
    def crear_especie_marina():
        __nombre_comun = input("Ingrese el nombre comun de la especie marina: ")
        __nombre_cientifico = input("Ingrese el nombre cientifico de la especie marina:")
        __promedio_vida = input("ingrese el promedio de vida de la especie marina: ")
        __tamanio_promedio = input("ingrese el tamanio promedio de la especie marina: ")
        __vertebrado = input("Escriba True en caso de que la especie sea vertebrado, caso contrario escriba False: ")
        linea = f"{__nombre_comun} {__nombre_cientifico} {__promedio_vida} {str(__tamanio_promedio)} {str(__vertebrado)}\n"
        return linea
        
    def borrar_especie_marina():
        especie_borrar = input("Ingrese el nombre de la especie que desea borrar")
        borrado = False
        for i in nombre:
            if(nombre_comun == i.nombre_comun):
                texto.remove(i)
                
                borrado = True
                break
                
    def menu():
        print("Puede eleginr una ocpcion\n")
        print("1) Ingresar una Especie Marina")
        print("2) Borrar una especie marina")
        print("3) Ver una Especie marina")
        print("4) Actualizar una Especie Marina")
        
        numero = input="Ingrese un numero"
        
        if numero == 1:
            crear_especie_marina()
        elif numero == 2:
            borrar_especie_marina()
        elif numero == 3:
            leer_archivo_especies()
        elif numero == 4:
            actualizar_especie_marina()
        elif numero < 1 or numero > 4:
            print("elija una opcion correcta")
            menu()
                
    #(crear_especie_marina())
    #leer_archivo_especies()
    menu()
# Out:
# Puede eleginr una ocpcion
#
# 1) Ingresar una Especie Marina
# 2) Borrar una especie marina
# 3) Ver una Especie marina
# 4) Actualizar una Especie Marina
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-6f09972e6719> in <module>
# ----> 1 class Especie_Maritima:
#       2
#       3     __vertebrado = False  # bool
#       4     __nombre_comun = None  # String
#       5     __nombre_cientifico = None  # string
#
# <ipython-input-9-6f09972e6719> in Especie_Maritima()
#      92     #(crear_especie_marina())
#      93     #leer_archivo_especies()
# ---> 94     menu()
#      95
#
# <ipython-input-9-6f09972e6719> in menu()
#      86         elif numero == 4:
#      87             actualizar_especie_marina()
# ---> 88         elif numero >1 or numero<4:
#      89             print("elija una opcion correcta")
#      90             menu()
#
# ...
