# %%
import numpy as np
import scipy.ndimage as ndimage
import scipy.misc as misc
import matplotlib.pyplot as plt
from random import choice
import PIL

# %%
imagen = misc.ascent()
imagen
# Out:
# array([[ 83,  83,  83, ..., 117, 117, 117],
#        [ 82,  82,  83, ..., 117, 117, 117],
#        [ 80,  81,  83, ..., 117, 117, 117],
#        ...,
#        [178, 178, 178, ...,  57,  59,  57],
#        [178, 178, 178, ...,  56,  57,  57],
#        [178, 178, 178, ...,  57,  57,  58]])

# %%
plt.imshow(imagen)
plt.show()

# %%
imagen.shape
# Out:
# (512, 512)

# %%
pt1= imagen[:256:1]
pt2 = imagen[257:512:]

# %%
plt.imshow(pt1)
plt.show()
plt.imshow(pt2)
plt.show()

# %%
imagen_array = np.array(imagen)
imagen_array.shape
print(imagen_array)
# Out:
# [[ 83  83  83 ... 117 117 117]
#  [ 82  82  83 ... 117 117 117]
#  [ 80  81  83 ... 117 117 117]
#  ...
#  [178 178 178 ...  57  59  57]
#  [178 178 178 ...  56  57  57]
#  [178 178 178 ...  57  57  58]]

# %%
np.split(imagen_array,2)
# Out:
# [array([[ 83,  83,  83, ..., 117, 117, 117],
#         [ 82,  82,  83, ..., 117, 117, 117],
#         [ 80,  81,  83, ..., 117, 117, 117],
#         ...,
#         [ 47,  38,  25, ..., 133, 132, 133],
#         [ 45,  45,  38, ..., 132, 133, 133],
#         [ 40,  41,  41, ..., 132, 133, 133]]),
#  array([[ 43,  43,  42, ..., 132, 132, 133],
#         [ 46,  44,  43, ..., 133, 133, 134],
#         [ 36,  35,  33, ..., 136, 136, 136],
#         ...,
#         [178, 178, 178, ...,  57,  59,  57],
#         [178, 178, 178, ...,  56,  57,  57],
#         [178, 178, 178, ...,  57,  57,  58]])]

# %%
corte_uno,corte_dos= np.split(imagen_array,2) #c1,c2,c3,c4 = np.split(imagen_array.flatten(),4)

# %%
plt.imshow(corte_uno)
c1,c2 = np.hsplit(corte_uno,2)
c3,c4 = np.hsplit(corte_dos,2)
plt.imshow(c4)
#c1.shape
#c1.reshape(256,256)
#c2.reshape(256,256)
#c3.reshape(256,256)
#c4.reshape(256,256)
#plt.imshow(c1.reshape(256,256))
c4.shape
# Out:
# (256, 256)

# %%
#cuadro_dos = np.hsplit(corte_v1,2)
#cuadro_tres,cuadro_cuatro = np.hsplit(corte_v2,2)
np.zeros(c1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-169-4ff102c7cecc> in <module>
#       1 #cuadro_dos = np.hsplit(corte_v1,2)
#       2 #cuadro_tres,cuadro_cuatro = np.hsplit(corte_v2,2)
# ----> 3 np.zeros(c1)
#
# ValueError: maximum supported dimension for an ndarray is 32, found 256

# %%
mitad1 = np.array([c1,c2])
mitad2 = np.array([c3,c4])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-168-844c75ba840e> in <module>
# ----> 1 mitad1 = np.array([np.zeros(c1),c2])
#       2 mitad2 = np.array([c3,c4])
#
# ValueError: maximum supported dimension for an ndarray is 32, found 256

# %%
#imagen_completa
#imagen_completa.shape

# %%
plt.imshow(c1)
plt.imshow(c2)
plt.imshow(c3)
plt.imshow(c4)

# %%
m1 = np.concatenate(mitad1,axis = 1)
m2 = np.concatenate(mitad2,axis = 1)

# %%
plt.imshow(np.concatenate([m1,m2]))

# %%
imagen_completa = np.array([c1,c2,c3,c4])
#print(type(imagen_completa))
mitad1 = np.array(imagen_completa[0],imagen_completa[1])
mitad2 = np.array(imagen_completa[2],imagen_completa[3])
m1 = np.concatenate(mitad1,axis = 1)
m2 = np.concatenate(mitad2,axis = 1)

plt.imshow(np.concatenate([m1,m2]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-167-e7b0942e8341> in <module>
#       1 imagen_completa = np.array([c1,c2,c3,c4])
#       2 #print(type(imagen_completa))
# ----> 3 mitad1 = np.array(imagen_completa[0],imagen_completa[1])
#       4 mitad2 = np.array(imagen_completa[2],imagen_completa[3])
#       5 m1 = np.concatenate(mitad1,axis = 1)
#
# TypeError: data type not understood
